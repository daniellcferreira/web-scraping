# %%
# projeto final
import pandas as pd
from bs4 import BeautifulSoup
from selenium import webdriver
from selenium.webdriver.common.by import By

# %%
# fazendo a pesquisa
url = "https://pt.wikipedia.org/wiki/Wikip%C3%A9dia:P%C3%A1gina_principal"

driver = webdriver.Firefox()

driver.get(url)

search_box = driver.find_element(By.NAME, "search")

search_box.send_keys("historia dolar americano")
search_box.submit()

# %%
# tratando os tipos de paginas
if driver.find_elements(By.XPATH, '/html/body/div[2]/div/div[3]/main/div[3]/div[3]/div[1]/div[1]/table/tbody/tr/td[1]/span/a/img'):
    print("pagina desanbiguação")
    driver.find_element(By.XPATH, '/html/body/div[2]/div/div[3]/main/div[3]/div[3]/div[1]/ul/li[1]/a').click()
elif driver.find_elements(By.XPATH, '//*[@id="firstHeading"]'):
    if driver.find_elements(By.XPATH, '//*[@id="firstHeading"]')[0].text == "Resultados da pesquisa":
        print("pesquisa avançada")
        driver.find_element(By.XPATH, '/html/body/div[2]/div/div[3]/main/div[3]/div[3]/div[3]/div[4]/ul/li[1]/div[2]/div[2]/div[1]/a').click()
    else:
        print("pagina wiki")

html = driver.page_source
driver.quit()
# Out:
# pesquisa avançada

# %%
print(html)
# Out:
# <html class="client-js vector-feature-language-in-header-enabled vector-feature-language-in-main-page-header-disabled vector-feature-sticky-header-disabled vector-feature-page-tools-pinned-disabled vector-feature-toc-pinned-clientpref-1 vector-feature-main-menu-pinned-disabled vector-feature-limited-width-clientpref-1 vector-feature-limited-width-content-enabled vector-feature-custom-font-size-clientpref-1 vector-feature-appearance-enabled vector-feature-appearance-pinned-clientpref-1 vector-feature-night-mode-disabled skin-theme-clientpref-day vector-toc-available" lang="pt" dir="ltr"><head>
# <meta charset="UTF-8">
# <title>Dólar dos Estados Unidos – Wikipédia, a enciclopédia livre</title>
# ...

# %%
html_parsed = BeautifulSoup(html, "html.parser")

tabelas = html_parsed.find_all("table")

for tabela in tabelas:
    df = pd.read_html(str(tabela))[0]
    print(df.head())
# Out:
# C:\Users\Daniel\AppData\Local\Temp\ipykernel_956\244412343.py:6: FutureWarning: Passing literal html to 'read_html' is deprecated and will be removed in a future version. To read from a literal string, wrap it in a 'StringIO' object.
#   df = pd.read_html(str(tabela))[0]
# C:\Users\Daniel\AppData\Local\Temp\ipykernel_956\244412343.py:6: FutureWarning: Passing literal html to 'read_html' is deprecated and will be removed in a future version. To read from a literal string, wrap it in a 'StringIO' object.
#   df = pd.read_html(str(tabela))[0]
# C:\Users\Daniel\AppData\Local\Temp\ipykernel_956\244412343.py:6: FutureWarning: Passing literal html to 'read_html' is deprecated and will be removed in a future version. To read from a literal string, wrap it in a 'StringIO' object.
#   df = pd.read_html(str(tabela))[0]
# ...
